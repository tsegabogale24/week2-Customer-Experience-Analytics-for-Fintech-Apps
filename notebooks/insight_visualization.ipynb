# %% [markdown]
#  Insights
# From the 1,200+ cleaned and labeled reviews:
#
#  Top Drivers of Satisfaction
# Smooth Transaction Experience
#
# 417 reviews praised speed and reliability of transactions.
#
# User Interface & Experience
#
# 624 reviews highlighted intuitive design and ease of use.
#
#  Top Pain Points
# Account Access Issues
#
# 151 complaints about login failures, password reset issues.
#
# Poor Customer Support
#
# Repeated frustration about lack of response/help (6 key cases).
#
#  Bank Comparison
# Commercial Bank of Ethiopia (CBE) had higher average sentiment.
#
# Dashen Bank showed more variance in ratings.
#
# BOA had the fewest complaints but also fewer strong positives.

# %%
import pandas as pd

import sys
import os
import importlib

# Add the directory containing the module to the path
sys.path.append(os.path.abspath("../scripts"))

# Import the whole module (not just the function)
import insights
# Reload the module after making code changes to it
importlib.reload(insights)
from insights import *

# Load your data
df = pd.read_csv("../data/final_themed_data.csv")

# Run individual analyses
analyze_sentiment_by_bank(df)
analyze_rating_distribution(df)

# Or run all analyses at once
run_all_analyses(df)
# Out:
# c:\Users\tsega\Desktop\week2-Customer-Experience-Analytics-for-Fintech-Apps\scripts\insights.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='app_name', y='rating', palette='pastel')
# c:\Users\tsega\Desktop\week2-Customer-Experience-Analytics-for-Fintech-Apps\scripts\insights.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='app_name', y='rating', palette='pastel')
